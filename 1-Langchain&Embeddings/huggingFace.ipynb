# %% [markdown]
# ## HuggingFace Embeddings

# %% [markdown]
# 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

# %%
import os 
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ['HUGGINGFACE_TOKEN']= os.getenv('HUGGINGFACE_TOKEN')

# %% [markdown]
# !pip install sentence_transformers
#
# LangChain_HuggingFace refers to the integration of LangChain with models from Hugging Face, enabling the use of Hugging Face's vast library of models within the LangChain framework.

# %% [markdown]
# ### Sentence Transformers on Hugging Face
#
# HuggingFace Sentence Transformers is a Python Framework for state of the art sentence, tet and image embeddings. One of the embedding model is used in huggingface embeddings class.
#
# We have also added an alias for SentenceTransformerEmbeddings for users who are more familiar with directly using package.

# %%
from langchain_huggingface import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
# Out:
# /home/ankitmishralive/Desktop/Ankit Mishra/Programming/Generative A.I -LLMs/Langchain/.venv/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %% [markdown]
# HuggingFaceEmbeddings(client=SentenceTransformer(
#   (0): Transformer({'max_seq_length': 384, 'do_lower_case': False}) with Transformer model: MPNetModel
#   (1): Pooling({'word_embedding_dimension': 768, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False, 'pooling_mode_weightedmean_tokens': False, 'pooling_mode_lasttoken': False, 'include_prompt': True})
#   (2): Normalize()
# ), model_name='sentence-transformers/all-mpnet-base-v2', cache_folder=None, model_kwargs={}, encode_kwargs={}, multi_process=False, show_progress=False)

# %%
text = "this is test documents "

query_result = embeddings.embed_query(text)

query_result
# Out:
# [-0.04171816259622574,
#  0.11281941831111908,
#  -0.050892896950244904,
#  0.04300248995423317,
#  0.046477001160383224,
#  -0.045548226684331894,
#  -0.024982407689094543,
#  0.04340580478310585,
#  0.0008784294477663934,
#  0.0320756733417511,
#  0.055097926408052444,
#  0.01737028732895851,
#  0.010812365449965,
#  0.019098056480288506,
#  -0.07424694299697876,
#  -0.03753488138318062,
#  -0.007921288721263409,
#  -0.030617358162999153,
#  0.0009401529678143561,
#  0.05901222303509712,
#  0.010624255053699017,
#  0.06765562295913696,
#  -0.02351284772157669,
#  -0.017335526645183563,
#  0.014076240360736847,
#  0.032086726278066635,
#  -0.058893557637929916,
#  -0.006175997667014599,
#  0.05348769575357437,
#  -0.05297493189573288,
#  0.04851382225751877,
#  0.06876010447740555,
#  0.05744510889053345,
#  0.06465805321931839,
#  0.07216169685125351,
#  -0.004591356497257948,
#  0.04926523193717003,
#  0.012884533032774925,
#  0.02475074492394924,
#  0.014489096589386463,
# ...

# %%
len(query_result)
# Out:
# 384

# %% [markdown]
# #### We can also do it for Embed Documents

# %%
doc_result = embeddings.embed_documents([text,"This is not a test document."])

doc_result
# Out:
# [[-0.041718125343322754,
#   0.11281943321228027,
#   -0.0508929118514061,
#   0.04300249367952347,
#   0.04647701233625412,
#   -0.045548249036073685,
#   -0.024982402101159096,
#   0.04340583458542824,
#   0.0008784512174315751,
#   0.03207564353942871,
#   0.05509793385863304,
#   0.01737026870250702,
#   0.010812363587319851,
#   0.019098088145256042,
#   -0.07424695789813995,
#   -0.037534911185503006,
#   -0.00792126264423132,
#   -0.030617352575063705,
#   0.0009401337592862546,
#   0.05901223048567772,
#   0.01062423549592495,
#   0.06765563040971756,
#   -0.023512866348028183,
#   -0.017335502430796623,
#   0.014076166786253452,
#   0.03208675608038902,
#   -0.058893561363220215,
#   -0.006176023278385401,
#   0.053487665951251984,
#   -0.05297492444515228,
#   0.048513829708099365,
#   0.06876010447740555,
#   0.05744507908821106,
#   0.06465807557106018,
#   0.07216167449951172,
#   -0.0045913709327578545,
#   0.049265239387750626,
#   0.012884560972452164,
# ...

# %%
len(doc_result)
# Out:
# 2

# %%
len(doc_result[0])
# Out:
# 384
